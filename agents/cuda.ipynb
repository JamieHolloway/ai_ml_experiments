# %%
# ─────────────────────────────────────────────────────────────────────────
import torch

if torch.cuda.is_available():
    print("CUDA is available")
    print(torch.version.cuda)
    print("Torch built with CUDA:", torch.version.cuda)
    print("GPU name:", torch.cuda.get_device_name(0))
    print("Runtime reports CUDA arch:", torch.cuda.get_device_capability(0))
else:
    print("CUDA is not available")
# Out:
# CUDA is available
# 11.8
# Torch built with CUDA: 11.8
# GPU name: NVIDIA GeForce GTX 1660 Ti
# Runtime reports CUDA arch: (7, 5)
