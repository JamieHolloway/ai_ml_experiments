# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate values for z
z = np.linspace(-5, 5, 400)
tanh = (np.exp(z) - np.exp(-z)) / (np.exp(z) + np.exp(-z))

plt.style.use('dark_background')
plt.figure(figsize=(6, 4))
plt.plot(z, tanh, linewidth=2)
plt.title('Tanh Function')
plt.xlabel('z')
plt.ylabel('tanh(z)')
plt.grid(True)
# plt.ylim(-0.1, 1.1)
plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)
plt.axhline(1, color='gray', linestyle='--', linewidth=0.5)
plt.axvline(0, color='red', linestyle='--', linewidth=1, label='z = 0')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('dark_background')

x = np.linspace(-5, 5, 400)

# Commenting out the numpy built-in:
y = np.tanh(x)

# Manual implementation:
# exp_x = np.exp(x)
# exp_neg_x = np.exp(-x)
# numerator = exp_x - exp_neg_x
# denominator = exp_x + exp_neg_x
# y = numerator / denominator

plt.figure(figsize=(8, 5))
plt.plot(x, y, label='tanh(x) implemented manually', linewidth=2)
plt.title('Hyperbolic Tangent (tanh) Activation Function (Manual Implementation)')
plt.xlabel('x')
plt.ylabel('tanh(x)')
plt.axhline(0, color='gray', linewidth=0.7, linestyle='--')
plt.axvline(0, color='gray', linewidth=0.7, linestyle='--')
plt.grid(alpha=0.2)
plt.legend()
plt.tight_layout()
plt.show()
